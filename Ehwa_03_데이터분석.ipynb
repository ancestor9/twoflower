# %% [markdown]
# ## **내 드라이브를 마운트하여 전체 압축파일에서 데이터 읽기**
# - 출현빈도 구하기

# %%
import pandas as pd
# %time df = pd.read_pickle('/content/drive/MyDrive/이대과제/df_gzip.pkl', compression='gzip')
df

# %%
# prompt: 일자와 언론사가 같은 행만 select

df = df[~df.duplicated(['일자', '언론사', '제목'])]
df
# Out:
#                일자    언론사                                    제목    통합 분류1  \
# 5        20100101   중도일보                   보령 농수특산물 직수출 100만달러     경제>무역
# 25       20100101   전북일보                 [사회적 기업을 찾아서]①진안 나눔푸드     지역>충남
# 45       20100101   경상일보                            금욜 편성표(1일)     문화>영화
# 65       20100101  헤럴드경제                  서초구, 불법 가스운반차량 ‘꼼작마!     지역>강원
# 85       20100101   데일리안           김문수 “2010년은 글로벌 리더로 도약하는 해”     지역>경기
# ...           ...    ...                                   ...       ...
# 7139904  20240521   매일신문  알리 테무 등 해외 직구, 안전성 논란 여전 "안전장치 만들어야"     경제>유통
# 7139944  20240521   울산신문                울산교육청, 시민참여예산 제안 사업 공모   사회>사회일반
# 7139964  20240521  아시아경제         경기공유학교 올해 1분기 도입 '학교밖 교육터' 역할  사회>교육_시험
# 7140004  20240521   노컷뉴스               "울산교육에 필요한 사업을 제안해 주세요"     지역>충남
# 7140024  20240523   세계일보                   제로 슈거 소주의 대표주자 '새로'  문화>미술_건축
#
#              통합 분류2     통합 분류3  \
# 5             경제>유통        NaN
# 25         경제>취업_창업      지역>울산
# 45            문화>출판   문화>방송_연예
# 65            지역>부산      지역>전남
# 85          경제>경제일반        NaN
# ...             ...        ...
# 7139904   경제>서비스_쇼핑      경제>무역
# 7139944       지역>충남      지역>충북
# 7139964       지역>경기      지역>충남
# 7140004       지역>경기      지역>충북
# 7140024    문화>방송_연예     경제>자동차
#
#                                                         기관  \
# 5                                                   유일,보령시
# 25       나눔푸드 일꾼,진안군,정부,녹수청산유과,지역아동센터,홍삼가공,사회복지,전북일보,행복...
# 45        현대,예술의전당,EBS,Iss,V리그,뉴스광장,대한민국,여전사,KBS,삼성,아앙,MBC
# 65                                            충전소,한국가스안전공사
# 85       덴마크,독일,일본,중국,동북아,경찰서,경기도,수도권,한반도,정부,OECD,사회복지,...
# ...                                                    ...
# 7139904   장관회의,테무,정부,관세청,인천본부세관,통계청,후부,인하대,KC,소비자학과,서울시,네일
# 7139944                        시민참여예산위원회,울산시교육청,시교육청,울산교육청
# 7139964  수원,이음,진로,도교육청,경기이룸대학,반도체공유학교,교원,경기,경기공유학교,용인,자...
# 7140004                          울산광역시교육청,울산시교육청,울산교육청,교육청
# 7140024                       롯데칠성음료,앰배서더,유튜브,현대,소주,한국,구미호
#
#                                          특성추출(가중치순 상위 50개)
# 5        미국,직수출,보령시,호주,농어민,보령,특산물,무한도전,해산물,서대,우럭,자반김,중간...
# 25       나눔푸드,일자리,진안군,참여자,근로취약계층,매출액,60대,지원금,사업단,장애인,진안...
# 45                          신년특집,2부,3부,수화방송,현대,1부,한국,삼성,아앙
# 65       가스용기,충전소,사업자,고압가스,겨울철,한국가스안전공사,판매업소,개별화물,최상윤,구...
# 85       경기도,수도권,대한민국,일자리,공직자,경쟁력,경인년,김문수,신년사,주년,중국,지방자...
# ...                                                    ...
# 7139904  소비자,알리,안전성,관세청,중국,서울시,발암물질,온라인,안전장치,어린이용품,유해물질...
# 7139944  시민참여예산,위원회,제안자,시교육청,울산,교직원,울산시교육청,5명,교육사업,5만,포...
# 7139964  경기공유학교,지역사회,반도체,관계자,김인숙,대학교수,공유학교,전문가,게임개발자,영화...
# 7140004  울산시교육청,울산,5만,교직원,울산광역시교육청,정책관,울산교육,상품권,제안자,기프티...
# 7140024  롯데칠성음료,한국,새로구미,앰배서더,소비자들,유튜브,소비자,매력적,코로나,체험관,성...
#
# [5641608 rows x 8 columns]

# %%
press = df['언론사']

# %%
import warnings
warnings.filterwarnings('ignore')

df= df[['일자', '특성추출(가중치순 상위 50개)']]

# df['일자']를 날짜로 변경하고 index로 지정
df['일자'] = pd.to_datetime(df['일자'], format='%Y%m%d')
df['년도']=df['일자'].apply(lambda x: x.year)
df['월']=df['일자'].apply(lambda x: x.month)

# %% [markdown]
# ### **저장한 전처리된 corpus 읽기(corpus생성에 시간이많이 걸려서)**

# %%
import pickle

with open('/content/drive/MyDrive/이대과제/filtered_corpus.pkl', 'rb') as f:
    filtered_corpus = pickle.load(f)

print(f'corpus 크기 {len(filtered_corpus)}')
# Out:
# corpus 크기 5641608

# %% [markdown]
# ### **Stop words 정의**

# %%
data = pd.read_excel('/content/drive/MyDrive/이대과제/불용어후보.xlsx')

stop_words = list(data[data['선택'] == 0]['단어'].tolist())


for i in press:   # df['언론사']
    stop_words.append(i)

for i in ['미국', '국내', '한국', '대표', '중국','일본', '가격', '글로벌', '기업', '대상', '정부', '세계', '국회', '관심', '방송'] :
    stop_words.append(i)

for i in ['인사', '발령', '공개모집', '필기시험', '발령', '인사 발령', '과장', '전보', '일자', '공무원', '국장', '점검', '실시'] :
    stop_words.append(i)

common = ["전략", "연구", "평가", "마련", "조사", "관리", "보다", "관련","전문가","예정","이번", "환경", "기술", "사업", "산업", "기업","우리나라", "또한",
          "총회", "대한", "통해", "한국","국내","개최","행사","우수","장관","피해","해외","일자리","박람회", "지원", "위해", "총회","국제","분야","세계",
          "식품과학","국립","시민","통합", "정책", "대해", '선정', '아시아경제']
for i in common :
    stop_words.append(i)

for i in ['두고', '농협', '시행', '식품안전', '안전', '참여', '이상', '조치', '개선', '관내', '참석', '대전', '확산', '조성', '홍보'] :
    stop_words.append(i)

for i in ['대한민국', '홈페이지', '상반기', '시간date', '이명박', '박근혜', '청와대', '위원회',
          '그동안', '1만', '회용', '사람들', '앤서니', '이재명', '더불어민주당', '민주당',
         '봉준호', '시상식', '만큼','위원장', '관계자', '서울', '국민의힘', '윤석열', 'a씨', '식품의약품안전처', '식약처','소비자들', '농림축산식품부',
         '식품부', '농식품부']:
    stop_words.append(i)

print(f'불용어_stop_words 개수는 {len(list(set(stop_words)))}')
# Out:
# 불용어_stop_words 개수는 2916

# %%
', '.join(stop_words)

# %%
# 샘플링: 예를 들어 전체 데이터의 10%만 사용
from sklearn.utils import resample
sampled_corpus = resample(filtered_corpus,
                          n_samples=int(0.1 * len(filtered_corpus)),
                          random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
import numpy as np

vect = CountVectorizer(stop_words = stop_words, ngram_range=(1, 1), min_df= 0.005, max_df= 0.8)
X = vect.fit_transform(sampled_corpus) # Doc-Term Matrix 계산
X = TfidfTransformer().fit_transform(X)

count = X.toarray().sum(axis=0) # Doc-Term Matrix 각 단어에 대한 합
idx = np.argsort(-count)
count = count[idx]

# Use get_feature_names_out() instead of get_feature_names()
feature_name = np.array(vect.get_feature_names_out())[idx]
keyword_list = list(zip(feature_name, count))
result_df = pd.DataFrame(keyword_list)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ebn', 'kbs', 'mbc', 'obs', 'pd', 'sbs', 'ytn', '시사in', '저널'] not in stop_words.
#   warnings.warn(

# %%
result_df.to_excel('/content/drive/MyDrive/이대과제/result_df_10pro.xlsx', index=False)

# %%
result_df  # 0.1 sampling
# Out:
#         0             1
# 0     온라인  17972.191630
# 1     소비자  13131.979130
# 2     편의점  12100.347921
# 3    빅데이터  10248.317778
# 4     캠페인   9716.027674
# ..    ...           ...
# 333    기부   1359.757079
# 334    아동   1339.473493
# 335    운동   1331.629088
# 336    실천   1290.253795
# 337    공동   1260.740469
#
# [338 rows x 2 columns]

# %%
# 시작년도, 끝년도 지정
start_year = 2017
end_year = 2022

corpus = [""] * len(df)

result_df = pd.DataFrame()

# 녇도별 문서 추출 후 키워드 빈도수 분석

for year in tqdm_notebook(range(int(start_year),int(end_year)+1)):
    start_date = str(year) + "-01-01"
    end_date = str(year) + "-12-31"
    dt_index = (df['일자'] >= start_date) & (df['일자'] <= end_date)
    temp_df = df[dt_index]

    # twitter 단어 추출이 필요없음
    #for i, fn in enumerate(temp_df['특성추출(가중치순 상위 50개)']) :
    #    corpus[i] = " ".join(twitter.nouns(fn))

    corpus = []
    for keywords in temp_df['특성추출(가중치순 상위 50개)']:
        corpus.append(keywords)


    vect = CountVectorizer(stop_words = stop_words, ngram_range=(1, 1), min_df= 0.005, max_df= 0.8)
    X = vect.fit_transform(corpus)
    X = TfidfTransformer().fit_transform(X)

    count = X.toarray().sum(axis=0)
    idx = np.argsort(-count)
    count = count[idx]

    feature_name = np.array(vect.get_feature_names())[idx]

    result = list(zip(feature_name, count))
    result = pd.DataFrame(result)
    result.columns=[str(year) + ' 키워드','빈도수']
    result_df = pd.concat([result_df,result],axis=1)

result_df.head(50)
